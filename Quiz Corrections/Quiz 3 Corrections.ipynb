# %%
# Question 1: Write a conditional statement that checks if x is less than 10 and greater than 4, and prints an appropriate message.
x = input("Enter an integer: ")
x = float(x)
if x % 1 != 0:
    print("Please enter an integer")

else:
    if x < 4:
        print("x is less than 4")
    elif 4 <= x <= 10:
        print("x is in between 4 and 10") # On the quiz in order for my statement to be true, I needed to flip the statements. However, for this one, I decided to change the elif and else statements to match the printed statement.
    else:
        print("x is greater than 10")
# Out:
# x is in greater than 10

# %%
# Question 2: Take user input for the value of a variable x.
# Check if the input is an integer or not (if it is not, you need to convert it into an int).
# Write your code to compute the factorial of x.
x = input("Enter a number: ")
x_float = float(x) # this turns the number we inputted as a str to a float.
print ("x = ", x_float) 

c = x_float % 1
print ("c = ", c) # This uses the modulus operator to check if the number is divisible by 0 to ensure the number is an integer.
# This number is also printed for in the output to confirm it's divisible by 0.

if c != 0:
    print ("Error. Please enter an integer.")

else:
    x_int = int(x_float)
    def factorial_iterative(c):
        result = 1
        for i in range(1, c + 1):
            result *= i
        return result

factorial_value = factorial_iterative(x_int)
print("The factorial of", x, "is", factorial_value)
# Out:
# x =  5.0
# c =  0.0
# The factorial of 5 is 120
