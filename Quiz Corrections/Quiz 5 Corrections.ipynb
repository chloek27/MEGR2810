# %%
# Question 1: Add comments after the # sign to explain what each line of code is doing:
text = "Happy Halloween" # A variable that is assigned a string text.
print(text[10]) # This only prints the 10th character of the string. NOT the 10 spaces. In this case it would only print out o, since it's the 10th character of the string.
print("Slice:", text[5:8]) # This slices the string, and although it starts from the space, it does not count the character the range is from. So this slice from 5 to 8, will not include the 8th character.
# THe slice will only give you Slice: Ha
# Out:
# o
# Slice:  Ha

# %%
# Question 2: Five errors are in the code below. Mark the errors
# I will mark the errors I got right, and the ones I missed with and explanation.
items = {'b': 10.0, 'e': 9.0, 'g': 7.5} # I forgot to fix the colon error. This gives you a syntaxerror as this is classified as a dictionary key, which needs a colon to pair it with a specified value.
total = 0.0
total_item = 0
for name, price in items.items(): # CORRECT (colon after for line))
    total += price # This line gives you an indentation error. After yesterday's lecture, the line under the command indicates the lines below it need indentation.
    total_item += 1 # Did not add a plus sign to the total item count, the result would show "for 1 items" which is incorrect. Now this should represent the count of all items listed in the dict key.
    print(f"{name} costs ${price:.2f}")
print(f"Total grocery bill is ${total:.2f} for {total_item} items") # CORRECT (use of {} not quotation marks)
# Also forgot to write out the whole printed line on the quiz. Needed to include "for 3 items" after the value of the total grocery bill.
# Out:
# b costs $10.00
# e costs $9.00
# g costs $7.50
# Total grocery bill is $26.50 for 3 items
